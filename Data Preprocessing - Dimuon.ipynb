# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import statistics
import scipy.stats as stats

df = pd.read_csv('Finaldimuon.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Type     Run      Event        E1      px1       py1       pz1  \
# 0       11386   GT  146511  267622505   7.53715 -5.18896  1.921050   5.11681
# 1       97339   GT  146510  146339837   8.58507  1.44816 -8.002430   2.74887
# 2       86600   GT  146510  104696928  36.63500 -4.86645 -9.812810 -34.95910
# 3       33498   GG  146511  493709438  12.05240 -4.90028 -4.251090  10.15700
# 4       22152   GG  146511  171399555   8.92358 -2.20703 -0.308785   8.64019
#
#         pt1      eta1  ...      eta2      phi2  Q2         M  Vector px Sum  \
# 0   5.53315  0.827155  ...  1.754790 -2.184080  -1   4.22848      -5.957816
# 1   8.13241  0.331887  ...  0.797469 -1.357460  -1   3.63056       2.989450
# 2  10.95320 -1.877380  ... -2.349540 -2.598880  -1   2.52726      -5.775715
# 3   6.48726  1.230660  ...  1.242620 -1.151140  -1   6.93281      -2.774610
# 4   2.22852  2.064460  ...  0.684614  0.256866  -1  11.84460       7.591400
#
# ...

# %%
E1 = df['E1']
Px1 = df['px1']
Py1 = df['py1']
Pz1 = df['pz1']
Pt1 = df['pt1']
Eta1 = df['eta1']
E2 = df['E2']
Px2 = df['px2']
Py2= df['py2']
Pz2= df['pz2']
Pt2= df['pt2']
Eta2 = df['eta2']
M = df['M']
VPXS = df['Vector px Sum']
VPYS = df['Vector py Sum']
VPZS = df['Vector pz Sum']
RPS = df['Resultant Momentum Sum']
FE = df['Final Energy']
Noise = df['ENERGY LOST']

# %%
## STANDARD DEVIATIONS FOR EACH COLUMN##
sdE1 = statistics.stdev(E1)
sdPx1 =statistics.stdev(Px1)
sdPy1 = statistics.stdev(Py1)
sdPz1 = statistics.stdev(Pz1)
sdPt1 = statistics.stdev(Pt1)
sdEta1 =statistics.stdev(Eta1)
sdE2 = statistics.stdev(E2)
sdPx2 = statistics.stdev(Px2)
sdPy2 = statistics.stdev(Py2)
sdPz2 = statistics.stdev(Pz2)
sdPt2 = statistics.stdev(Pt2)
sdEta2 = statistics.stdev(Eta2)
sdM = statistics.stdev(M)
sdVPXS = statistics.stdev(VPXS)
sdVPYS = statistics.stdev(VPYS)
sdVPZS = statistics.stdev(VPZS)
sdRPS = statistics.stdev(RPS)
sdFE = statistics.stdev(FE)
sdNoise = statistics.stdev(Noise)

# %%
## MEAN-AVERAGE VALUE FOR EACH COLUMN ##
meanE1 = statistics.mean(E1)
meanPx1 =statistics.mean(Px1)
meanPy1 = statistics.mean(Py1)
meanPz1 = statistics.mean(Pz1)
meanPt1 = statistics.mean(Pt1)
meanEta1 =statistics.mean(Eta1)
meanE2 = statistics.mean(E2)
meanPx2 = statistics.mean(Px2)
meanPy2 = statistics.mean(Py2)
meanPz2 = statistics.mean(Pz2)
meanPt2 = statistics.mean(Pt2)
meanEta2 = statistics.mean(Eta2)
meanM = statistics.mean(M)
meanVPXS = statistics.mean(VPXS)
meanVPYS = statistics.mean(VPYS)
meanVPZS = statistics.mean(VPZS)
meanRPS = statistics.mean(RPS)
meanFE = statistics.mean(FE)
meanNoise = statistics.mean(Noise)

# %%
print(sdE1)
print(sdPx1)
print(sdPy1)
print(sdPz1)
print(sdPt1)
print(sdEta1)
print(sdE2)
print(sdPx2)
print(sdPy2)
print(sdPz2)
print(sdPt2)
print(sdEta2)
print(sdM)
print(sdVPXS)
print(sdVPYS)
print(sdVPZS)
print(sdRPS)
print(sdFE)
print(sdNoise)
# Out:
# 16.135048301668597
# 6.70928465530578
# 7.359713080291401
# 22.27770673226513
# 5.9471651243731705
# 1.4896499038488589
# 10.596456151413788
# 4.553044542681766
# 5.649060007664455
# 11.40308583515123
# 5.7530284347417515
# 1.518989946661385
# 10.547518707904734
# 7.892641893832153
# 8.27389248639515
# 27.965663745670724
# 20.17840345421396
# 20.09806273353383
# 3.493526035356951e-05

# %%
print(meanE1)
print(meanPx1)
print(meanPy1)
print(meanPz1)
print(meanPt1)
print(meanEta1)
print(meanE2)
print(meanPx2)
print(meanPy2)
print(meanPz2)
print(meanPt2)
print(meanEta2)
print(meanM)
print(meanVPXS)
print(meanVPYS)
print(meanVPZS)
print(meanRPS)
print(meanFE)
print(meanNoise)
# Out:
# 18.32251256540203
# 0.0048552458424542325
# -0.3573629843257682
# -0.6668837624687313
# 7.996098615039462
# -0.08782450746091904
# 8.412526797203638
# 0.03554844168655102
# 0.28724856193497855
# 0.5378341899523457
# 4.430366851788791
# 0.06340177300240375
# 9.72638305596731
# 0.04040375737800969
# -0.0701144161610913
# -0.12904957849104604
# 22.487208574452005
# 26.73501028096699
# 2.9081740667701614e-05

# %%
## TO BE FINALIZED -- Zscores for all values##
zscoreE1 = stats.zscore(E1)
zscorePx1 = stats.zscore(Px1)
zscorePy1 = stats.zscore(Py1)
zscorePz1 = stats.zscore(Pz1)
zscorePt1 = stats.zscore(Pt1)
zscoreEta1 = stats.zscore(Eta1)
zscoreE2 = stats.zscore(E2)
zscorePx2 = stats.zscore(Px2)
zscorePy2 = stats.zscore(Py2)
zscorePz2 = stats.zscore(Pz2)
zscorePt2 = stats.zscore(Pt2)
zscoreEta2 = stats.zscore(Eta2)
zscoreM = stats.zscore(M)
zscoreVPXS = stats.zscore(VPXS)
zscoreVPYS = stats.zscore(VPYS)
zscoreVPZS = stats.zscore(VPZS)
zscoreRPS = stats.zscore(RPS)
zscoreFE = stats.zscore(FE)

# %%
upperE1 = meanE1 + (3 * sdE1)
lowerE1 = meanE1 - (3 * sdE1)
for i in range(len(zscoreE1)):
    if zscoreE1[i] > upperE1 or zscoreE1[i] < lowerE1:
        print(i)

# %%
upperPx1 = meanPx1 + (3 * sdPx1)
lowerPx1 = meanPx1 - (3 * sdPx1)
for i in range(len(zscorePx1)):
    if zscorePx1[i] > upperPx1 or zscorePx1[i] < lowerPx1:
        print(i)

# %%
upperPy1 = meanPy1 + (3 * sdPy1)
lowerPy1 = meanPy1 - (3 * sdPy1)
for i in range(len(zscorePy1)):
    if zscorePy1[i] > upperPy1 or zscorePy1[i] < lowerPy1:
        print(i)
# Out:
# 49896

# %%
upperPz1 = meanPz1 + (3 * sdPz1)
lowerPz1 = meanPz1 - (3 * sdPz1)
for i in range(len(zscorePz1)):
    if zscorePz1[i] > upperPz1 or zscorePz1[i] < lowerPz1:
        print(i)

# %%
upperPt1 = meanPt1 + (3 * sdPt1)
lowerPt1 = meanPt1 - (3 * sdPt1)
for i in range(len(zscorePt1)):
    if zscorePt1[i] > upperPt1 or zscorePt1[i] < lowerPt1:
        print(i)
# Out:
# 49896

# %%
upperEta1 = meanEta1 + (3 * sdEta1)
lowerEta1 = meanEta1 - (3 * sdEta1)
for i in range(len(zscoreEta1)):
    if zscoreEta1[i] > upperEta1 or zscoreEta1[i] < lowerEta1:
        print(i)

# %%
upperE2 = meanE2 + (3 * sdE2)
lowerE2 = meanE2 - (3 * sdE2)
for i in range(len(zscoreE2)):
    if zscoreE2[i] > upperE2 or zscoreE2[i] < lowerE2:
        print(i)
# Out:
# 31982
# 48989
# 49773

# %%
upperPx2 = meanPx2 + (3 * sdPx2)
lowerPx2 = meanPx2 - (3 * sdPx2)
for i in range(len(zscorePx2)):
    if zscorePx2[i] > upperPx2 or zscorePx2[i] < lowerPx2:
        print(i)
# Out:
# 24217
# 31982
# 40561
# 48861
# 48972
# 48989
# 49733
# 49746
# 49749
# 49827

# %%
upperPy2 = meanPy2 + (3 * sdPy2)
lowerPy2 = meanPy2 - (3 * sdPy2)
for i in range(len(zscorePy2)):
    if zscorePy2[i] > upperPy2 or zscorePy2[i] < lowerPy2:
        print(i)
# Out:
# 40561
# 48989
# 49773

# %%
upperPz2 = meanPz2 + (3 * sdPz2)
lowerPz2 = meanPz2 - (3 * sdPz2)
for i in range(len(zscorePz2)):
    if zscorePz2[i] > upperPz2 or zscorePz2[i] < lowerPz2:
        print(i)
# Out:
# 31982
# 49773

# %%
upperPt2 = meanPt2 + (3 * sdPt2)
lowerPt2 = meanPt2 - (3 * sdPt2)
for i in range(len(zscorePt2)):
    if zscorePt2[i] > upperPt2 or zscorePt2[i] < lowerPt2:
        print(i)
# Out:
# 31982
# 40561
# 48972
# 48989
# 49773

# %%
upperEta2 = meanEta2 + (3 * sdEta2)
lowerEta2 = meanEta2 - (3 * sdEta2)
for i in range(len(zscoreEta2)):
    if zscoreEta2[i] > upperEta2 or zscoreEta2[i] < lowerEta2:
        print(i)

# %%
upperM = meanM + (3 * sdM)
lowerM = meanM - (3 * sdM)
for i in range(len(zscoreM)):
    if zscoreM[i] > upperM or zscoreM[i] < lowerM:
        print(i)

# %%
upperVPXS = meanVPXS + (3 * sdVPXS)
lowerVPXS = meanVPXS - (3 * sdVPXS)
for i in range(len(zscoreVPXS)):
    if zscoreVPXS[i] > upperVPXS or zscoreVPXS[i] < lowerVPXS:
        print(i)

# %%
print(df)
# Out:
#        Unnamed: 0 Type     Run      Event         E1       px1        py1  \
# 0           11386   GT  146511  267622505    7.53715  -5.18896   1.921050
# 1           97339   GT  146510  146339837    8.58507   1.44816  -8.002430
# 2           86600   GT  146510  104696928   36.63500  -4.86645  -9.812810
# 3           33498   GG  146511  493709438   12.05240  -4.90028  -4.251090
# 4           22152   GG  146511  171399555    8.92358  -2.20703  -0.308785
# ...           ...  ...     ...        ...        ...       ...        ...
# 49917       66318   GT  146514  266116849  117.23500 -36.86280  -2.487730
# 49918        7611   GT  146511   33471677  175.29500 -36.97890  40.877500
# 49919       38656   GT  146511  332740529  166.51300  11.55530 -32.721200
# 49920       42531   GT  146511  164244768  198.33100  54.89460  19.601900
# 49921       87389   GT  146510  121218699  102.48000   7.84822 -16.999600
#
#              pz1       pt1      eta1  ...      eta2      phi2  Q2         M  \
# ...

# %%
upperE1 = meanE1 + (3 * sdE1)
lowerE1 = meanE1 - (3 * sdE1)
upperPx1 = meanPx1 + (3 * sdPx1)
lowerPx1 = meanPx1 - (3 * sdPx1)
upperPy1 = meanPy1 + (3 * sdPy1)
lowerPy1 = meanPy1 - (3 * sdPy1)
upperPz1 = meanPz1 + (3 * sdPz1)
lowerPz1 = meanPz1 - (3 * sdPz1)
upperPt1 = meanPt1 + (3 * sdPt1)
lowerPt1 = meanPt1 - (3 * sdPt1)
upperEta1 = meanEta1 + (3 * sdEta1)
lowerEta1 = meanEta1 - (3 * sdEta1)
upperE2 = meanE2 + (3 * sdE2)
lowerE2 = meanE2 - (3 * sdE2)
upperPx2 = meanPx2 + (3 * sdPx2)
lowerPx2 = meanPx2 - (3 * sdPx2)
upperPy2 = meanPy2 + (3 * sdPy2)
lowerPy2 = meanPy2 - (3 * sdPy2)
upperPz2 = meanPz2 + (3 * sdPz2)
lowerPz2 = meanPz2 - (3 * sdPz2)
upperPt2 = meanPt2 + (3 * sdPt2)
lowerPt2 = meanPt2 - (3 * sdPt2)
upperEta2 = meanEta2 + (3 * sdEta2)
lowerEta2 = meanEta2 - (3 * sdEta2)
upperM = meanM + (3 * sdM)
lowerM = meanM - (3 * sdM)
upperVPXS = meanVPXS + (3 * sdVPXS)
lowerVPXS = meanVPXS - (3 * sdVPXS)
upperVPYS = meanVPYS + (3 * sdVPYS)
lowerVPYS = meanVPYS - (3 * sdVPYS)
upperVPZS = meanVPZS + (3 * sdVPZS)
lowerVPZS = meanVPZS - (3 * sdVPZS)
upperRPS = meanRPS + (3 * sdRPS)
lowerRPS = meanRPS - (3 * sdRPS)
upperFE = meanFE + (3 * sdFE)
lowerFE = meanFE - (3 * sdFE)


##ITERATION##
for i in range(len(df)):
    if zscoreE1[i] > upperE1 or zscoreE1[i] < lowerE1:
        df.drop(i)
    if zscorePx1[i] > upperPx1 or zscorePx1[i] < lowerPx1:
        df.drop(i)
    if zscorePy1[i] > upperPy1 or zscorePy1[i] < lowerPy1:
        df.drop(i)
    if zscorePz1[i] > upperPz1 or zscorePz1[i] < lowerPz1:
        df.drop(i)
    if zscorePt1[i] > upperPt1 or zscorePt1[i] < lowerPt1:
        df.drop(i)
    if zscoreEta1[i] > upperEta1 or zscoreEta1[i] < lowerEta1:
        df.drop(i)
    if zscoreE2[i] > upperE2 or zscoreE2[i] < lowerE2:
        df.drop(i)
    if zscorePx2[i] > upperPx2 or zscorePx2[i] < lowerPx2:
        df.drop(i)
    if zscorePy2[i] > upperPy2 or zscorePy2[i] < lowerPy2:
        df.drop(i)
    if zscorePz2[i] > upperPz2 or zscorePz2[i] < lowerPz2:
        df.drop(i)
    if zscorePt2[i] > upperPt2 or zscorePt2[i] < lowerPt2:
        df.drop(i)
    if zscoreEta2[i] > upperEta2 or zscoreEta2[i] < lowerEta2:
        df.drop(i)
    if zscoreM[i] > upperM or zscoreM[i] < lowerM:
        df.drop(i)
    if zscoreVPXS[i] > upperVPXS or zscoreVPXS[i] < lowerVPXS:
        df.drop(i)
    if zscoreVPYS[i] > upperVPYS or zscoreVPYS[i] < lowerVPYS:
        df.drop(i)
    if zscoreVPZS[i] > upperVPZS or zscoreVPZS[i] < lowerVPZS:
        df.drop(i)
    if zscoreRPS[i] > upperRPS or zscoreRPS[i] < lowerRPS:
        df.drop(i)
    if zscoreFE[i] > upperFE or zscoreFE[i] < lowerFE:
        df.drop(i)

# %%
print(df)
# Out:
#        Unnamed: 0 Type     Run      Event         E1       px1        py1  \
# 0           11386   GT  146511  267622505    7.53715  -5.18896   1.921050
# 1           97339   GT  146510  146339837    8.58507   1.44816  -8.002430
# 2           86600   GT  146510  104696928   36.63500  -4.86645  -9.812810
# 3           33498   GG  146511  493709438   12.05240  -4.90028  -4.251090
# 4           22152   GG  146511  171399555    8.92358  -2.20703  -0.308785
# ...           ...  ...     ...        ...        ...       ...        ...
# 49917       66318   GT  146514  266116849  117.23500 -36.86280  -2.487730
# 49918        7611   GT  146511   33471677  175.29500 -36.97890  40.877500
# 49919       38656   GT  146511  332740529  166.51300  11.55530 -32.721200
# 49920       42531   GT  146511  164244768  198.33100  54.89460  19.601900
# 49921       87389   GT  146510  121218699  102.48000   7.84822 -16.999600
#
#              pz1       pt1      eta1  ...      eta2      phi2  Q2         M  \
# ...
